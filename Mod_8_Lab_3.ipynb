# %% [markdown]
# <a href="https://colab.research.google.com/github/Narendra190/FMML-22B21A4371/blob/main/Mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 17:50:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   200MB/s    in 0.3s
#
# 2024-03-25 17:50:13 (200 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31768   0911.2904v4  This paper describes a methodology for detecti...    cs
# 19012   1301.6733v1  In previous work, we pointed out the limitatio...    cs
# 22026   1312.2646v4  The question of how to determine the number of...  stat
# 24750   1411.4568v3  We introduce a learning-based approach to dete...    cs
# 23028  1802.04725v2  We consider the learning of multi-agent Hawkes...  stat
# ...             ...                                                ...   ...
# 20574  1607.00791v1  This paper introduces mathematical formalism f...    cs
# 6123   1607.08810v1  Polynomial networks and factorization machines...  stat
# 39630  1610.09908v1  This article describes the implementation of t...    cs
# 377    1803.05407v1  Deep neural networks are typically trained by ...    cs
# 28619  1707.02725v2  In this paper, we present a simple and modular...    cs
#
#                                                    title  year  \
# 31768  Sequential anomaly detection in the presence o...  2009
# 19012  SPOOK: A System for Probabilistic Object-Orien...  2013
# 22026  Guaranteed Model Order Estimation and Sample C...  2013
# 24750     TILDE: A Temporally Invariant Learned DEtector  2014
# 23028  Superposition-Assisted Stochastic Optimization...  2018
# ...                                                  ...   ...
# 20574  Formal analysis of HTM Spatial Pooler performa...  2016
# 6123   Polynomial Networks and Factorization Machines...  2016
# 39630  Joint Large-Scale Motion Estimation and Image ...  2016
# 377    Averaging Weights Leads to Wider Optima and Be...  2018
# 28619  Interleaved Group Convolutions for Deep Neural...  2017
#
#                                                 keywords
# 31768  [describes, methodology, detecting, anomalies,...
# 19012  [limitations, framework, structured, expressiv...
# 22026  [determine, independent, dirichlet, allocation...
# 24750  [introduce, repeatable, keypoints, conditions,...
# 23028  [processes, containing, processes, endogenous,...
# ...                                                  ...
# 20574  [introduces, mathematical, formalism, hierarch...
# 6123   [polynomial, factorization, efficiently, inter...
# 39630  [describes, implementation, estimation, recons...
# 377    [typically, optimizing, conjunction, convergen...
# 28619  [modularized, architecture, interleaved, convo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31768    [describes, methodology, detecting, anomalies,...
# 19012    [limitations, framework, structured, expressiv...
# 22026    [determine, independent, dirichlet, allocation...
# 24750    [introduce, repeatable, keypoints, conditions,...
# 23028    [processes, containing, processes, endogenous,...
#                                ...
# 955      [recurrent, architecture, recurrent, controlli...
# 14387    [described, representation, documents, disting...
# 22559    [proceedings, interpretable, barcelona, procee...
# 11016    [recursive, algorithm, separable, nonnegative,...
# 319      [similarity, clustering, imensional, computing...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8768 words.
# Out of those 4537 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02621da5-549d-440f-a752-df708cc32b02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02621da5-549d-440f-a752-df708cc32b02")) {                    Plotly.newPlot(                        "02621da5-549d-440f-a752-df708cc32b02",                        [{"x":["programming","measurement","successive","anomalies","universal","available","detecting","dimensionality","prediction","filtering","distributions","estimated","coincides","synthetic","exponential","describes","sequential","distribution","marginals","detection","sublinear","methodology","potentially","corresponding","likelihood","assigning","observations","parameter","sequentially","threshold","comparing","potential","posterior","algorithms","computing","applications","algorithm","structured","implemented","arbitrary","compactly","probabilistic","naturally","represent","magnitude","approaches","empirically","knowledge","representation","implements","structure","fundamental","awareness","limitations","interesting","addresses","framework","inference","existence","relations","uncertainty","expressive","importance","selection","estimation","implications","necessitate","nonparametric","performance","parameters","allocation","determine","complexity","application","procedure","independent","exchangeable","practical","dirichlet","guaranteed","beforehand","outperforms","candidates","temporally","detectors","keypoints","invariant","influence","conditions","significantly","introduce","sensitive","untrained","achieving","suppression","surprisingly","challenging","regressor","viewpoint","different","properties","beneficial","accordingly","containing","demonstrated","exogenous","operation","effectiveness","tightening","superposition","intensities","processes","demonstrate","convergence","endogenous","associated","functions","recommendation","optimization","stochastic","diversity","overcoming","minimizer","mathematically","established","generalize","conditioning","numerically","empirical","regression","condition","limitation","minimization","characterizing","efficiently","attributed","sensitivity","guarantees","relatively","classification","similarity","additional","information","complementary","demonstrating","distributional","integrated","integrating","relatedness","recognizing","submission","identification","difficulty","according","differently","significant","predicted","illumination","challenge","simulations","variations","simultaneously","scenarios","acquiring","mechanism","extensive","estimating","extracted","enhancement","robustness","particularly","conventional","comparison","leveraging","obstructed","determines","appearances","improving","demanding","controlled","reliability","collected","featuring","experimental","movements","appearance","prototype","experiments","percentile","statistical","underlying","asymptotically","resulting","converges","efficiency","dimensional","parametric","illustrate","computational","increasing"],"y":[129,32,11,12,27,290,68,59,212,50,113,55,3,119,39,89,68,186,13,348,13,75,50,115,72,18,75,118,19,31,84,156,45,615,135,416,812,107,103,72,4,156,61,115,48,455,73,334,359,21,327,79,14,75,76,63,553,215,33,96,98,39,77,155,205,21,1,16,932,225,42,59,223,227,116,123,4,127,25,28,1,283,33,25,34,9,67,60,128,303,314,56,2,86,7,30,279,10,18,765,202,24,15,51,101,5,45,184,2,5,6,104,599,115,0,115,231,33,307,121,51,4,2,13,42,52,13,7,149,118,45,23,57,20,154,9,31,59,52,549,143,127,691,38,26,21,56,38,7,41,9,123,45,100,10,260,45,31,164,40,74,108,99,12,117,156,65,113,30,97,81,106,143,48,2,18,6,119,6,38,25,87,5,363,14,83,24,574,2,144,106,12,161,31,152,167,41,63,286,98],"type":"bar"},{"x":["programming","measurement","successive","anomalies","universal","available","detectin ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4537,), (4537, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8233333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.613899613899614);'>Automatic</span> <span style=''>White</span> <span style=''>Blood</span> <span style=''>Cell</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Measuring</span> <span style=''>Aid</span> <span style=''>for</span> <span style=''>Medical</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>Diagnosis</span> <br/><br/><span style=''>Blood</span> <span style=''>related</span> <span style=''>invasive</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pathological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigations</span> <span style=''>play</span> <span style=''>a</span> <span style=''>major</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>diagnosis</span> <span style=''>of</span> <span style=''>diseases</span> <span style=''>But</span> <span style=''>in</span> <span style=''>India</span> <span style=''>and</span> <span style=''>other</span> <span style=''>third</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>countries</span> <span style=''>there</span> <span style=''>are</span> <span style=''>no</span> <span style=''>enough</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pathological</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>infrastructures</span> <span style=''>for</span> <span style=''>medical</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>diagnosis</span> <span style=''>Moreover</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>remote</span> <span style=''>places</span> <span style=''>of</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>countries</span> <span style=''>have</span> <span style=''>neither</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pathologists</span> <span style=''>nor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physicians</span> <span style=''>Telemedicine</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>solves</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physicians</span> <span style=''>But</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pathological</span> <span style='background-color:rgba(0, 255, 0, 0.47169811320754723);'>investigation</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>infrastructure</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>integrated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>telemedicine</span> <span style='background-color:rgba(0, 255, 0, 0.6206896551724138);'>technology</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>is</span> <span style=''>to</span> <span style=''>automate</span> <span style=''>the</span> <span style=''>blood</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pathological</span> <span style='background-color:rgba(0, 255, 0, 0.47169811320754723);'>investigation</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.5466666666666666);'>Detection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.35518157661647476);'>different</span> <span style=''>white</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.43283582089552247);'>automated</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>and</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Models</span> <span style=''>a</span> <span style=''>Gentle</span> <span style=''>Tutorial</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>tutorial</span> <span style=''>we</span> <span style=''>explain</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>(GPLVM)</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>page</span> <span style=''>limit</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivation</span> <span style=''>given</span> <span style=''>in</span> <span style=''>Titsias</span> <span style=''>(2009)</span> <span style=''>and</span> <span style=''>Titsias</span> <span style=''>Lawrence</span> <span style=''>(2010)</span> <span style=''>is</span> <span style=''>brief</span> <span style=''>hence</span> <span style=''>getting</span> <span style=''>a</span> <span style=''>full</span> <span style=''>picture</span> <span style=''>of</span> <span style=''>it</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collecting</span> <span style=''>results</span> <span style=''>from</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>sources</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>algebra</span> <span style=''>to</span> <span style=''>fill</span> <span style=''>in</span> <span style=''>the</span> <span style=''>gaps</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>thus</span> <span style=''>to</span> <span style=''>collect</span> <span style=''>all</span> <span style=''>the</span> <span style=''>results</span> <span style=''>and</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivations</span> <span style=''>into</span> <span style=''>one</span> <span style=''>place</span> <span style=''>to</span> <span style=''>help</span> <span style=''>speed</span> <span style=''>up</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>this</span> <span style=''>work</span> <span style=''>In</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>re</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrisation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>it</span> <span style=''>to</span> <span style=''>be</span> <span style=''>carried</span> <span style=''>out</span> <span style=''>in</span> <span style=''>parallel</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Tensor</span> <span style=''>vs</span> <span style=''>Matrix</span> <span style=''>Methods</span> <span style=''>Robust</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style=''>under</span> <span style=''>Block</span> <span style=''>Sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perturbations</span> <br/><br/><span style=''>Robust</span> <span style=''>tensor</span> <span style=''>CP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>involves</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposing</span> <span style=''>a</span> <span style=''>tensor</span> <span style=''>into</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteed</span> <span style=''>recovery</span> <span style=''>It</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternates</span> <span style=''>between</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>CP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>through</span> <span style=''>gradient</span> <span style=''>ascent</span> <span style=''>(a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tensor</span> <span style=''>power</span> <span style=''>method)</span> <span style=''>and</span> <span style=''>hard</span> <span style='background-color:rgba(255, 0, 0, 0.4347826086956522);'>thresholding</span> <span style=''>of</span> <span style=''>the</span> <span style=''>residual</span> <span style=''>We</span> <span style=''>prove</span> <span style='background-color:rgba(255, 0, 0, 0.31547619047619047);'>convergence</span> <span style=''>to</span> <span style=''>the</span> <span style=''>globally</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>under</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incoherence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>and</span> <span style=''>bounded</span> <span style=''>level</span> <span style=''>of</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbations</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>our</span> <span style=''>method</span> <span style=''>with</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>baselines</span> <span style=''>which</span> <span style=''>apply</span> <span style=''>robust</span> <span style=''>matrix</span> <span style=''>PCA</span> <span style=''>either</span> <span style=''>to</span> <span style=''>the</span> <span style=''>em</span> <span style=''>flattened</span> <span style=''>tensor</span> <span style=''>or</span> <span style=''>to</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>slices</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tensor</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>can</span> <span style=''>provably</span> <span style=''>handle</span> <span style=''>a</span> <span style=''>far</span> <span style=''>greater</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <span style=''>Assisted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>analysis</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Extracting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>magnetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resonance</span> <span style=''>images</span> <span style=''>(fMRI)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>major</span> <span style=''>area</span> <span style=''>of</span> <span style=''>research</span> <span style=''>for</span> <span style=''>many</span> <span style=''>years</span> <span style=''>but</span> <span style=''>is</span> <span style=''>still</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demanding</span> <span style=''>more</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Nowadays</span> <span style=''>we</span> <span style=''>have</span> <span style=''>a</span> <span style=''>plenty</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>behavior</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>more</span> <span style=''>precise</span> <span style=''>methods</span> <span style=''>Thus</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionary</span> <span style=''>Learning</span> <span style=''>method</span> <span style=''>that</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>external</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>the</span> <span style=''>studied</span> <span style=''>problem</span> <span style=''>through</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>where</span> <span style=''>several</span> <span style=''>tests</span> <span style=''>show</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>other</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09932360270558918)
# 	knowledge (0.11890352438590246)
# 	automatic (0.07440370238519046)
# 	architecture (0.09113563545745818)
# 	segmentation (0.07618369526521894)
# 	information (0.24599501601993592)
# 	detection (0.1238875044499822)
# 	convolutional (0.13171947312210752)
# 	different (0.27233891064435745)
# 	recognition (0.13065147739409042)
#
# Some Statistics words are:
# 	variables (0.14163736815670516)
# 	theoretical (0.14766449020592667)
# 	algorithm (0.38724259166248115)
# 	stochastic (0.14465092918131592)
# 	estimation (0.1772978402812657)
# 	statistical (0.1617277749874435)
# 	inference (0.19588146659969866)
# 	distribution (0.18734304369663485)
# 	dimensional (0.19387242591662482)
# 	regression (0.18232044198895028)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cf28af17-6700-4673-9cd0-1101a7214bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf28af17-6700-4673-9cd0-1101a7214bcb")) {                    Plotly.newPlot(                        "cf28af17-6700-4673-9cd0-1101a7214bcb",                        [{"x":["programming","measurement","successive","anomalies","universal","available","detecting","dimensionality","prediction","filtering","distributions","estimated","coincides","synthetic","exponential","describes","sequential","distribution","marginals","detection","sublinear","methodology","potentially","corresponding","likelihood","assigning","observations","parameter","sequentially","threshold","comparing","potential","posterior","algorithms","computing","applications","algorithm","structured","implemented","arbitrary","compactly","probabilistic","naturally","represent","magnitude","approaches","empirically","knowledge","representation","implements","structure","fundamental","awareness","limitations","interesting","addresses","framework","inference","existence","relations","uncertainty","expressive","importance","selection","estimation","implications","necessitate","nonparametric","performance","parameters","allocation","determine","complexity","application","procedure","independent","exchangeable","practical","dirichlet","guaranteed","beforehand","outperforms","candidates","temporally","detectors","keypoints","invariant","influence","conditions","significantly","introduce","sensitive","untrained","achieving","suppression","surprisingly","challenging","regressor","viewpoint","different","properties","beneficial","accordingly","containing","demonstrated","exogenous","operation","effectiveness","tightening","superposition","intensities","processes","demonstrate","convergence","endogenous","associated","functions","recommendation","optimization","stochastic","diversity","overcoming","minimizer","mathematically","established","generalize","conditioning","numerically","empirical","regression","condition","limitation","minimization","characterizing","efficiently","attributed","sensitivity","guarantees","relatively","classification","similarity","additional","information","complementary","demonstrating","distributional","integrated","integrating","relatedness","recognizing","submission","identification","difficulty","according","differently","significant","predicted","illumination","challenge","simulations","variations","simultaneously","scenarios","acquiring","mechanism","extensive","estimating","extracted","enhancement","robustness","particularly","conventional","comparison","leveraging","obstructed","determines","appearances","improving","demanding","controlled","reliability","collected","featuring","experimental","movements","appearance","prototype","experiments","percentile","statistical","underlying","asymptotically","resulting","converges","efficiency","dimensional","parametric","illustrate","computational","increasing","staggering","centuries","supervised","situations","dramatically","covariate","therefore","concisely","interestingly","continuum","singularity","regularization","numerical","generalization","motivated","isotropic","theoretical","consequence","including","strategies","performances","predictive","complexities","necessarily","regularizations","inhomogeneous","favorable","homogeneity","candidate","reproducing","preferred","homogeneous","applicable","precision","considered","advantages","multithreaded","versatile","frameworks","recognition","disadvantages","comparative","architectures","especially","conclusions","platforms","handwritten","activation","performed","proportional","transitions","probability","comparisons","accomplished","transition","similarities ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	endogenous
# 	nonnegativity
# 	misspecified
# 	marginalised
# 	minimizers
# 	katehakis
# 	extrapolate
# 	extrapolating
# 	contextualizing
# 	immigration
# 	ferromagnetic
# 	nonstationary
# 	reparametrizations
# 	reparametrization
# 	subpopulations
# 	underestimation
# 	missforest
# 	suspected
# 	gaussianity
# 	blockwise
# Some words which never appear in Statistics papers:
# 	keypoints
# 	untrained
# 	illumination
# 	obstructed
# 	appearances
# 	staggering
# 	centuries
# 	multithreaded
# 	authoring
# 	locomotive
# 	allocated
# 	unaffected
# 	effortless
# 	morphologically
# 	mandatory
# 	breathing
# 	animation
# 	dissipation
# 	neuromorphic
# 	plasticity

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.064946210194011e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
